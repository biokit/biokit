# %%
# %pylab inline
from biokit import viz
import mpld3
mpld3.disable_notebook()
import pandas as pd
matplotlib.rcParams['figure.dpi'] = 160
matplotlib.rcParams['figure.figsize'] = (10,8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from biokit.viz import corrplot

# %%
_ = reload(corrplot)

# %%
import string
letters = string.uppercase[0:10]
df = pd.DataFrame(dict(( (k, np.random.random(10)+ord(k)-65) for k in letters)))
# add perturbation
df = df.corr()
df.ix[2,1] = -1
df.ix[1,2] = -1
c = corrplot.Corrplot(df.corr())

# %%
w,h = df.shape
#df

# %%
c.plot(colorbar=False, method='square', shrink=.9 ,rotation=45   )

# %%
c.plot(method='text', fontsize=8)

# %%
c.plot(method='color')

# %%
c.plot(method='pie', shrink=.8)

# %%
c.plot(colorbar=False, method='circle', shrink=.9, type='lower'  )

# %%
c.plot(colorbar=False, method='circle', shrink=.9, type='upper'  )
