# %%
from biokit import viz

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X0 = (random.random(100) - 0.5)*2
X1 = random.random(100) + abs(X0)

# %%
import biokit.viz

# %%
from biokit.viz.volcano import Volcano

# %%
v = Volcano(X0, X1)

# %%
v.plot(fold_change_threshold=0.4)
